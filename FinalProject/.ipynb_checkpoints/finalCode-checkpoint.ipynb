# %%
text = open("Scripts/oneLiners.txt", "r").read().lower()

maxlen = 60

step = 3

sentences = []

next_chars = []

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
# Out:
# Number of sequences: 10673

# %%
chars = sorted(list(set(text)))
print('Unique Characters:', len(chars))
# Out:
# Unique Characters: 49

# %%
char_indices = dict((char, chars.index(char)) for char in chars)

# %%
import numpy as np
import random

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
from keras import layers
import keras

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

optimizer = keras.optimizers.RMSprop(lr=0.01, clipnorm=1.)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From D:\PyCharm\PyCharmProject\cs344\venv\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import sys

for epoch in range(1, 10):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=32,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 0.75, 1.0]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(500):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# WARNING:tensorflow:From D:\PyCharm\PyCharmProject\cs344\venv\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
# 10673/10673 [==============================] - 8s 785us/step - loss: 2.5610
# --- Generating with seed: "ness, but it sure makes misery easier to live with.
#
# i disco"
# ------ temperature: 0.2
# ness, but it sure makes misery easier to live with.
#
# i discore the the the sot a bestare the the the to the the then in then the the the the the the the the and the the the to the the son to the then ther the sot to the pot to the southe the the the the then a tore the thon to the then ats a toon in a cort in the to southe the the soos the son’t to co the the the they the pond in a then then tor to the the tor the soon the the the the the the son then the son’t to the the son son’t are tore to soust a ping to the the the then the the pithe the then the t
# ------ temperature: 0.5
# oust a ping to the the the then the the pithe the then the to they is you tor and the my tos a doast mo soon in poon’t tosseang mopling it.
#
# you then the the somtialle hotsthen mang to soust in and the you is so to and whong the to not tor the cof fortite my i witot of.
#
# in theing a to the in a thon forn a card then the theades astatten thand on then a thon of is a toopl of iss whe tos a that to the soithe in to kest allite dot it in toret consting of sou thon the in you and and ine.
#
# the the butt a sount to pon’s than’t the tostot the sither andey wher
# ------ temperature: 0.75
# tt a sount to pon’s than’t the tostot the sither andey wher contine i hand doouste the to the care aedrery is a it ineit inst sor thiy.
#
# molcisoond in thing a piy cestre toy honas is bits you toe sot toet an the sounnattings the sot buth the son’nesyou thonn’t ing anlhy.
#
# indn.
#
# ther to forss to whenca et i towad is as ancilienehavey
#
#
# tore are cost, asspus atproon of fan a donve cane on.
#
# haad onahe blat chenwhen mithonct ins albicherry you.
#
# whe citrrons than a la pi’n andorery thoninstoese a cind corigeas'and a cing muy a sistees tho soute ofi ofiinse
# ------ temperature: 1.0
# cind corigeas'and a cing muy a sistees tho soute ofi ofiinsebs soharlay.
#
# d rlyses aaci’lyt tre allitstit thin’t ofot foor, twiglithis aciglitritfis sofbine at isleclsm.
#
# .
#
# it forttreamige, poathieytemcashinedd cuc aos is, , thet.
#
# dord whan -omt its a kattoer.
#
# youtt conpieniesthe n mopn bes.
#
# i’cy thissee, pesand go smepruad astikr oo.
#
#  men of ins of som so
# nine mefaninynitt, coomven cay a ussouf cost’llarufon.
#
# tes sotn enne worsre.
#
# yon the piad as urletinvingith, to boputhit’t.
#
# in foowhhe of.
#
# handith p
# ne muty che voncapeco they,
# fuve if, cateoe
# epoch 2
# Epoch 1/1
# 10673/10673 [==============================] - 10s 942us/step - loss: 2.1509
# --- Generating with seed: "eople hear voices.
# .
#  some see invisible people.
# .
#  others h"
# ------ temperature: 0.2
# eople hear voices.
# .
#  some see invisible people.
# .
#  others han the sare a care the sater the ereace a care the care the can the san think the sare the sare is the sare the sare a cane the and the sare a cane the sare the proor ither are the dor a can the sale a care a can the are the and the same is the sare the and the san the sare the and the same the sare a cane the sare the sare the sare the and the sare the sare the are a cane the sare the care the sare a can the cane then the sare the san the san the sare the sare the can then is the san the sare a
# ------ temperature: 0.5
# the san the sare the sare the can then is the san the sare as the dare things when that in and a that whin the then it sane why is people that the fring then think is in and a cant the promisn and the mon the the then it then sting a can it a a cane a cane thing and you the proon the hare then is the ’t may are care a care is the sime thing is the sane as that is a cant of it same that worn the then the sae that a cans mearly is ppore that ithe cange a nout than a can thinks a care that go hand a dorey a care is hane roally the hat the cance a dige thit
# ------ temperature: 0.75
# a dorey a care is hane roally the hat the cance a dige thit way i was itner is go the kidcaly are it think and is diytonen are the enopre think dromow sriok in saritelivorsed a ablo wes niver whon dofiges the smith is when the are the vent is chom mon why bus as ary is prod tay noon you whint a ronkunn a dat thee dinty mom same hom is thang thinger is there cant the cudpeic, the mantmugse then a than reatay way is homar and a piga
#  indran stien think is a caak a saven you stay trey iall they ither can and a dillings thole a care it not in mygot thind you
# ------ temperature: 1.0
# er can and a dillings thole a care it not in mygot thind you lefes -cors evertark thay thath thonse tome wwahk a dang when think on li’t stor that ligher thane us abeing, in loate you in dor then pare, there thet” itrte sads ther dorfions tales is froil dids dmesiichu thang cinpptonly are col nomings yau.
#
# tht nive to tho dy
# ig that inmidnstoneud.
#
# llen whins net eversear the deves is thash thetgapnithe .
# oar then’t whyns the say you a cotole ther, ar p
# i’t domseadly nom gof hor twather a soved than thin’t mall wiklis a ca saes thandser nop is whi hane t
# epoch 3
# Epoch 1/1
# 10673/10673 [==============================] - 9s 830us/step - loss: 1.9575
# --- Generating with seed: "n you are after it as when you are in it.
#
# some people hear "
# ------ temperature: 0.2
# n you are after it as when you are in it.
#
# some people hear i pand and the nat the arear a care the and the are the and the and i mastica to to same and but is and the are are the that i man you and the nat it and the and the and is the net the and the of i man you and the alligh the ared the are the prople is a cand the same and the are the are the and you and the arous is the whan i mas a to so to some a pooply and you and a prople the are the and the bar the areaplige the stor a prople and but the say the areaplige the proplesting is the arestica to t
# ------ temperature: 0.5
# t the say the areaplige the proplesting is the arestica to the first firfam.
#
# i sos in my not ead in nd caus dons but is not have that the aallich firnng the ally allite and the asticause te say when you and i on the never people is you and the arestice a cond to have and you and the that is the have and tre lige thing of the is and a coppe at to have and the tall the wasn’t have a price to sead to some i tas compon.
#
# he proploaning you tor is the not the have are the beaply.
#
# i was it and but it is has you and the new a does the sally.
#
# i mantidy.
#
# i ha
# ------ temperature: 0.75
# t is has you and the new a does the sally.
#
# i mantidy.
#
# i has the daforienes.
#
# is a day.
#  the nepe to  pooply haw shing you still a somet is nut the not is aste pritot to stild homes hat have not ald fifcerie nesgiths.
#
# the that i’l donas to have in the nut is bet aad but when cont un you end to to to hot the tare river.
#
# swope it and list.
#
# dismens ont the frop plicp is sull but some with lice and i tis ht fur my of pill able undiin aseare to dine.
#
# .
#  the boor an don’t the done peope all dow than soupre ning sam things mes the figh newey i han you and
# ------ temperature: 1.0
# han soupre ning sam things mes the figh newey i han you and sould nead the soun all and afareae.
#
# i han astidn thame a alldhict lessersica…on bes, the rica.
#
# dwict ely jupdronaubinte.
#
# in notild.
#
# endigly.
#
# iuver uutttyersasp,sill.
#
# in chloth for frreew dofmet, a onok you lifery.
#
# chan and ased cis vinmysthen undollice ie glok youg all a cous afpebause not wall be ustilany wo, have cand it lise a pith any geta  ussie dats if suplipe, lefutife geven th trato my’od wore dofkegaten.
#  a you snleamd breum.
#
# i liss canle thes same condory.
#
# the wise har ya for
# epoch 4
# Epoch 1/1
# 10673/10673 [==============================] - 9s 846us/step - loss: 1.7811
# --- Generating with seed: "e store in the airport?
#  a place to buy a piece of luggage?
# "
# ------ temperature: 0.2
# e store in the airport?
#  a place to buy a piece of luggage?
# if it who han the bes who theme a some to sememsting the somether when you doing the someone theme the the to the to the someone soof in the the procerang the somether who wrong.
#
# the sound theme a the to the the to the some theme the sound think you does are themes the say theme the somether the some to the somether when you dorst is the somether theme a someting the somethen when you’re them theme the some theme the sound theme the somether theme a thing the sore the somether who with a semit
# ------ temperature: 0.5
# omether theme a thing the sore the somether who with a semit the ersachuseryan a the to the secaute.
#
# when you thene the soors i cind ithers indint tole theme the refrige to semoth a reachle stopsed and think in it your oncorme and when thay wor don’t and a tor hame.
#
# why is the neverybus it is think you’re there a canding in the soop i say to and when the proces.
#
# when you them.
#
# when when you wrong in of men when the trues.
#
# when you does what the reast.
#
# corsead wore the to the the be to to the sof the sound bogh and be the to meln whan to the sofes t
# ------ temperature: 0.75
# he sof the sound bogh and be the to meln whan to the sofes there them who to seady and a vecering peaning
# a pornon driees.
#
# of you thank when a the sary’t home a say to han when thiles a lite.
#
# thriendy usme.
#
# i pichution.
#
# whin you’le s.
#
# its to hared a diegbress sons soy hard and he thing you dring a viclery.
#
# you’re ned that your mubse.
#
# never in recout tien to the ind be torme money a thath to be are the trupsing
# wipe themnenfer, with a cersones.
#
# loles and the worflise.
#
# whtneer with you’re the ither werers you’re corome are the looking the good he
# ------ temperature: 1.0
# e the ither werers you’re corome are the looking the good heinge.
#
# seech worn them, whence diane.
#
# leassedings eversind is whas is whit thank youed than… who my themeeongy conounthan mine all thers thing ille.
#
# don’in to somethey iadegedust work of be ally.
#  dois biglate.
#
# erenting co te mast for howr frour't trio on you’re nedy.
#  tomienienus.
#
# onry and and dipery.
#  itns good themper sowtings for evili,  vinkievgevers.
#
# my but pustiri, byly when do ssin conothel soosbaetebbe, bead.
#
# chem.
#
# doe.
#
# i you a so statathey hady.
#
# a pegame tions eveimy scrunn ha
# epoch 5
# Epoch 1/1
# 10673/10673 [==============================] - 10s 953us/step - loss: 1.6168
# --- Generating with seed: "it was your fault, i said i was blaming you.
#
# god must love "
# ------ temperature: 0.2
# it was your fault, i said i was blaming you.
#
# god must love the sare at the sare ther who wore the sigetien they care and man you the will they was the sare to the sare and the sare ther people is mistay.
#
# i hat the sare ther who wore the sime and then you don’t men the sare ther who wark the sime and then ied to read the sare ther who wark men the sare ther who wark the sime the sare at the sare ther when you then you don’t men the sare at the sare ther people is minuse the sare ther who wark a pare and is the sare ther who wark the sare and is it wank
# ------ temperature: 0.5
#  pare and is the sare ther who wark the sare and is it wank a bemange the seping soom in the menube the differ they care when you will one to somet in the mast a porort the some in the then you are the wast they the sare ther for the ware then ies the liget is the sunt in the some in the then you wand a leaple maney net is it whone is mego in me hears.
#
# i sowe a bang to somethen for for somether people is it wite men the sigetion.
#  then you wand a pigather.
#
# i ’s differ who sare and in the never the sare they who wark be are in the esare is men tale are
# ------ temperature: 0.75
#  the sare they who wark be are in the esare is men tale are sint is the erotaes.
#
# i wilo nood everytare thas in to sime.
#
# when you do the reat the wars the diget is with someone mest someone modester, is to seem the farst makn doing to is it’s mantane and thing in the said the sime so runn eaces is heard me in the tomeone men you wan does with neven for lose my the ?
# amath mes not im sount wore do seedy or ald life help runn is the insters.
#
# i lise to you somet is hispors.
#
# i you waid dornew sount a doge.
#
# wey with a sary is it with the rost one.
#
# i his
# ------ temperature: 1.0
# nt a doge.
#
# wey with a sary is it with the rost one.
#
# i his the sife and matter.
#
# jugly nald beduooon howr beach if sumen and , telling soom for hom the opame on a balo poin thing in the doing and read ther who wantue dienutol they with belinerseactiesy.
#
#  pormw how ware storn aive a saremty.
#
# i wank .
#  the rest.
#
# does are in the ssare but oor peopre is comlaal is peokong aly wobl, you mobe a for the moned get eataay life.
#
# a sine is coon an isn ad, peach to well ahve it’s diance.
#
# he sohel.
#  hemone teeppestreling mnsther fof issme then for mi
# not ided w
# epoch 6
# Epoch 1/1
# 10673/10673 [==============================] - 10s 966us/step - loss: 1.4696
# --- Generating with seed: "et - you can hide, but you can't run.
#
# velcro - what a rip-o"
# ------ temperature: 0.2
# et - you can hide, but you can't run.
#
# velcro - what a rip-ore the store a proter the someone bet the bes the sof in a prowerstare the sight the sare the bes that when you the bes the sof a prower, but in a care the sige a proter people the sare the signt the bess from proter the sun a prowerstare the bes what when you the stries.
#
# it’s have a precerausted the bes the bes the same the sight the sare the sof in a cameter is the sare the bes that when you the bes the tom the stries.
#
# i list the bes the sex of the restore the bes the bes the sare the sof in
# ------ temperature: 0.5
# s the sex of the restore the bes the bes the sare the sof in tried things you stre people mistist and the right the bes pill and the bes go bes you a compers.
#  it who lank and the rimes the stot a prose thinks in and if you the sreath when you the bus the bess frremes than intalk the bust and the bore who wrongs the warter beraces hat the kist the differen the bes wist and never best the bust and you the tom the prower changas the sersbasf the sefsies.
# n’t staid the trow have a careet the bess are the bess, better why dom hat the arout a proter peache th
# ------ temperature: 0.75
# re the bess, better why dom hat the arout a proter peache the bes mandy talls.
#
# the thoog are stud itaplets are the sighore the teppreti’t someone the sever with youreevelase.
#
# it’s all you can’t chemegather why wor ?
#  the differ coop never and realicef the can hat worr, but in am mateers urever reallyys the came the estitieny when you do not wetce the r stupnd life go ted selly are monee is everytast poold when i that the thot mess.
#
# itly misngat when you differen men in tr nutter for pifluing at the that whi hour from din.
#
# ihsre with and bus gi.
#
# the
# ------ temperature: 1.0
# at the that whi hour from din.
#
# ihsre with and bus gi.
#
# the comele, why wastriaproblestaren ffare the compors cossed peopoohh se acoullys firht wos blais my oteord fe tameshed the ref to mo sliver.
#
# hey wory hat shoo geve all ht leing the borfks tulls insostidfe.
#
# i list ’t the capave corrunn us to never corfen and to .
#
# you said
# a piltipess.
#  in of god a peraogly un whingtor you wrether peopleit toiverohes.
#  the right, his lovery lise the wardoor domenter nisticn thinks us ches.
#
# the thome the bess, the fiest at the fart the besh is a recledincersolionh
# epoch 7
# Epoch 1/1
# 10673/10673 [==============================] - 10s 957us/step - loss: 1.3458
# --- Generating with seed: "ery and all of their hopes and dreams.
#  if i didn’t drink th"
# ------ temperature: 0.2
# ery and all of their hopes and dreams.
#  if i didn’t drink thay mane a prother mans a camilles all your ble the same the same a probable the same things you will never bet you are all till the same is who wall seed the same the same things is my the same is who wall han sex you are and be a probable the same things are the same the same is who wall shat when you the storn why what you than selses are the same things are the same is a camilles and read things are the same the same to sellys, but the same the same things and remad things you din’t when you
# ------ temperature: 0.5
# he same the same things and remad things you din’t when you are and said a probes , the intollt bill yer thourtpees who wall does consn’t good that what you din’t will they the deffie the sild of inspet the same is mo stuplidy.
#  the same is people, why is a probable.
#
# if you dearn for the sear in a san worn live is when you are and be the same in a deapse it worn proble, in and it’s hall who are a samite, but a sait to say to sex and a came right is men looging is what you say to sex progad what even is it to stoilg a proties.
#
# why is of cance of lice to
# ------ temperature: 0.75
#  even is it to stoilg a proties.
#
# why is of cance of lice to never has someoony way frieves what sellwills, they areman sermifule st time chame them go bo things the same to in at the work chare the from my difting whing whis done is it whilg.
#
# frurn a revery is loar is maally lite tell sex eveuse you.
#
# i rant itwor.
#
# i difnere who fill , be tay is it then live is a deach the wall list to mo  and to plight ste.
#
# i say till why are sare at iloor of just knd frimndes to doing on you suntle the sime the eapen why are a cann’t lete.
#
# it’s it mass.
#
# in people
# ------ temperature: 1.0
# e the eapen why are a cann’t lete.
#
# it’s it mass.
#
# in people, we sanes where lour intver haced.
#
# does are the forgly first be on fropidnang six started.
# istion who war, you a probsceace that the firs mactlee, buy the who waterring over who w
# tce now, wheceute, deach goor who didn’t when you meart to me on yournes is that when you.
#
# evency whing with you a p pooseod frives all sone time you gooring as forg they are tomeone lase and blang wite a woy to the unaing bent in to bling , is who wall fut won’t cootrerstover fur that.
#
# when searf all yourre the un
# epoch 8
# Epoch 1/1
# 10673/10673 [==============================] - 9s 859us/step - loss: 1.2515
# --- Generating with seed: "ble down the stairs.
#
# never, under any circumstances, take a"
# ------ temperature: 0.2
# ble down the stairs.
#
# never, under any circumstances, take a ban souse all the be the sare the bell then you differen for think you don’t have i sad to starn is the say to hall your of in the sare the sale the sigas the can villates it’s cand to sex it will have the strien thin the stain thin inthe tall then your helle all your ely mills is the same think on your hall then you don’t can the street whine ge my blaig the sare the tille then your offere the sof of stry all thing is the sare the sare the sale to sellys in the sare the say of still thinks ind
# ------ temperature: 0.5
# e the sale to sellys in the sare the say of still thinks indot the strientase it it cand to be a carale the sof of the less, then you don’t you’re then your pleally , be out of men the tall the sof the cale of stull what the sign think the good out.
#  the time it will, but the mes it walk the somethen think on your healf sull the man in milling is a can be the be his miss
# angeat manters in prople, bit it walk the segas the coutters.
#
# a cigsed to sex it wisn the someone who who died.
#
# i don’t canve a carsed to stry allat to be a dident the same to hall how
# ------ temperature: 0.75
# e a carsed to stry allat to be a dident the same to hall how i kindaing to bely bace all tall then you can’t chen it wasted all teld of meare in the bove strienven think in at the tall siless for longide when your tell peally sind to hall all did.
#
# evenates.
#
# a cignitace us the doen fight thing i wan le, but it and mis consting so one ch is make one being to sometely i has think thoug stride the not wit like cille thing a cagally in the alliget think i talk money get monuy usleacat soubout you don’t may unie life
# then your vellly dof.
#
# if at thing tes ma
# ------ temperature: 1.0
# on’t may unie life
# then your vellly dof.
#
# if at thing tes make us souble.
#
# dorseltive all them god hat the wime a million sers.
#
# it’s fry prot things .
#
# stly disteact.
#
# it walk and for was with i you’lly coffeet to figg of you’re inood wreally pornt mayd myica simble all firt onnence is miss a gevent the probles.
#
# i didn’t make one ney’r bly picted to men ie of couldi.
#
# onnee are then unlaget and thine siles the colpuot and never thinki’t the lithe streep thing i panlrice whilrt, but it.
#
# if youy high a prinx of in corone.
#
# a shotebouy youg of purating b
# epoch 9
# Epoch 1/1
# 10673/10673 [==============================] - 10s 921us/step - loss: 1.1792
# --- Generating with seed: "e a beer gut, i have a protective covering for my rock hard "
# ------ temperature: 0.2
# e a beer gut, i have a protective covering for my rock hard when you the stuplize as who who who who who who wark a press, think you stot when you stoll is a camptith you wall they was do stupid thing and all you difference betor he the good than sone the stried.
#  a stust in the difference betor have a precent the same the that who who who who who who when you stoll who who who who who who who wreed and all the stort.
#
# i hat the nees way the that when you they gateries they was doing the safiely and who wall have a pread thin seed and and beting stien th
# ------ temperature: 0.5
#  and who wall have a pread thin seed and and beting stien that the not when you store ather farth fight the soffous to all the safieny blain fpridle.
#
# whate re the comot worry abe about to seer ausection.
#
# why do not when you tank a presed miss from piss they of you the cantice is the doney what you the geot was don’t the can differen the cousl who who when go the good and and beting betor you are apsolice is a care the get the prood who work not ducfing live then ild the wart a seapnitist is the the beaply pist a woo hat the does in truss.
#
# i will have
# ------ temperature: 0.75
# e the beaply pist a woo hat the does in truss.
#
# i will have a pread who can pigh to hell you dan tall when love a care the get eay.
#
# how the tom have yougle they who deess.
#
# i hat hill who who sone there care geot whe light the time think you spide and betire beto..
# .
#
# he not worr, but ready.
#  are dying so ton may difference betor whll say if all the last to mis a wand to the sried
# ersblad.
#
# i innn come that who wroll, cimpore died.
#
# wis has the never bas the time us stidn thin the differen for now the you talk the stust a reperted thing a saidling you m
# ------ temperature: 1.0
# now the you talk the stust a reperted thing a saidling you my can dies call when you.
#
# he lidt
#
# yun end to smoullives my pout the what  of who lefest a prut it cald in the cost.
#
# iwh.
#
# i ef
#
#  vited and you talk the sebon of spid how thrust saipgivismang bothert all the difference wis convo who heas on the bastion.
#
# i spell who wrolem
#
#  hat making ne ont makes are prealives, then fing belast ?
#  thewn’t you heep in pecrifars inn diff.
#
# eryin ?
#  sliffiendets had with you’re seeepobens looking recopoles.
#
# why do fene the bagebe the beers, must of when thues.
